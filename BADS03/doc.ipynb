# %%
import pandas as pd
df1= pd.read_excel(io= "/Users/hp/Downloads/Bank_Transactions_Feb2025_Jan2026.xlsx",sheet_name="Sheet1")

# %%
df1.drop(0,axis=0,inplace=True)

# %%
df1.columns = final.columns

# %%
df1.shape
# Out:
# (452, 6)

# %%
df1.drop(0,inplace=True)

# %%
df1.columns =df1.iloc[0,:]

# %%
df1.drop(["Column3","Column5","Column9"],axis=1,inplace=True)

# %%
d = df1.dropna(subset="Date",)

# %%
df_1 = df1.dropna().reset_index(drop=True)

# %%
d = df1.drop("Transaction Type",axis=1)

# %%
final.drop("Unnamed: 6",axis=1,inplace=True)

# %%
d.columns = final.columns

# %%
final.columns
# Out:
# Index(['Date', 'Particulars', 'Chq No/ReF No', 'Withdrawal', 'Deposit',
#        'Balance'],
#       dtype='object')

# %%
final = pd.concat([final,df1])

# %%
final.shape
# Out:
# (1119, 6)

# %%
final.drop(["Date(Value Date)","Ref No.\n/Cheque No","Debit(Rs)","Credit(Rs)","Balance(Rs)"],axis=1,inplace=True)

# %%
final
# Out:
#                       Date                                        Particulars  \
# 0              26 Jan 2026                             UPI/602641260853/DR/Go
# 1              25 Jan 2026                            UPI/602512447086/DR/Pol
# 2              25 Jan 2026                             UPI/639190202642/CR/SA
# 3              25 Jan 2026                             UPI/602535643841/DR/SU
# 4              25 Jan 2026                            UPI/639128987799/DR/Ind
# ..                     ...                                                ...
# 116  12-Nov-25 (12-Nov-25)       UPI/531620277109/DR/mr yadav velum\n/YES/UPI
# 117  11-Nov-25 (11-Nov-25)         UPI/531524570486/DR/PRADHAN MANTRI/YES/UPI
# 118  11-Nov-25 (11-Nov-25)         UPI/531549327455/DR/PRADEEP KUMAR /UBI/UPI
# 119  11-Nov-25 (11-Nov-25)                   APY-SI/MNTLY/QTRLY/HLFRLY\n/YRLY
# 120  11-Nov-25 (11-Nov-25)  Int.Pd:01-08-2025 to 31-10-2025:\n129501000015436
#
# ...

# %%
final.to_excel("iob_and_indusind_and_Kotak.xlsx")

# %%
impo

# %%
final.loc[:,"Withdrawal"].replace("-",0,inplace=True)
# Out:
# /var/folders/tn/6j9xy4y51cnbfstw_b9jl9mr0000gn/T/ipykernel_9635/2086570236.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   final.loc[:,"Withdrawal"].replace("-",0,inplace=True)

# %%
final["Withdrawal"] = final["Withdrawal"].astype(float)

# %%
final.sort_values(by="Withdrawal",ascending=False)
# Out:
#                       Date                                        Particulars  \
# 2    22-Jan-26 (22-Jan-26)       UPI/602290649727/DR/sangeetaprajap\n/IOB/UPI
# 14   25-Dec-25 (25-Dec-25)        UPI/535905504922/DR/ KALURAM/YES\n/Verified
# 310            26 May 2025               UPI/HIRA OMKAR GENE/551209013060/UPI
# 479            24 Feb 2025      ATM CASH TXN/INDUSIND BANK LIMITED MUMBAI M H
# 384            17 Jun 2025               UPI/HIRA OMKAR GENE/516811421395/UPI
# ..                     ...                                                ...
# 438            15 Jan 2026   UPI/MR RUSHABH VIJA/601564142059/Payment from sl
# 443            28 Jan 2026               UPI/HITESH KUKARAM /602870337205/UPI
# 445            30 Jan 2026  Recd:IMPS/603031559568/GOOGLEINDI/KKBK /X2063/...
# 447            30 Jan 2026               UPI/JYOTI ARUN KUMA/603079413289/UPI
# 448            30 Jan 2026               UPI/JYOTI ARUN KUMA/603043018147/UPI
#
# ...
