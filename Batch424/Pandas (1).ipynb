# %% [markdown]
# # Pandas

# %%
pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 3.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/11.5 MB 5.9 MB/s eta 0:00:02
#    -- ------------------------------------- 0.6/11.5 MB 6.8 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/11.5 MB 6.3 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.4/11.5 MB 6.4 MB/s eta 0:00:02
#    ------ --------------------------------- 1.9/11.5 MB 6.6 MB/s eta 0:00:02
#    -------- ------------------------------- 2.3/11.5 MB 6.5 MB/s eta 0:00:02
#    --------- ------------------------------ 2.8/11.5 MB 6.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.3/11.5 MB 6.6 MB/s eta 0:00:02
#    ------------ --------------------------- 3.6/11.5 MB 6.3 MB/s eta 0:00:02
# ...

# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
# Using cached pandas-2.2.3-cp313-cp313-win_amd64.whl (11.5 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
pip install Pyarrow
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/25.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/25.7 MB ? eta -:--:--
#    -- ------------------------------------- 1.3/25.7 MB 3.9 MB/s eta 0:00:07
#    --- ------------------------------------ 2.1/25.7 MB 3.8 MB/s eta 0:00:07
#    ---- ----------------------------------- 3.1/25.7 MB 4.1 MB/s eta 0:00:06
#    ------ --------------------------------- 3.9/25.7 MB 4.1 MB/s eta 0:00:06
#    ------- -------------------------------- 5.0/25.7 MB 4.1 MB/s eta 0:00:05
#    --------- ------------------------------ 6.0/25.7 MB 4.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 7.3/25.7 MB 4.5 MB/s eta 0:00:05
#    ------------- -------------------------- 8.7/25.7 MB 4.6 MB/s eta 0:00:04
#    -------------- ------------------------- 9.4/25.7 MB 4.7 MB/s eta 0:00:04
# ...

# %% [markdown]
# pandas data table representation
# <img src="https://pandas.pydata.org/docs/_images/01_table_dataframe.svg" style="background-color: white;"><br>
# To manually store data in a table, create a DataFrame. When using a Python dictionary of lists, the dictionary keys will be used as column headers and the values in each list as columns of the DataFrame.
# <br>A DataFrame is a 2-dimensional data structure that can store data of different types (including characters, integers, floating point values, categorical data and more) in columns. It is similar to a spreadsheet, a SQL table or the data.frame in R.

# %%
pip install --upgrade pandas
# Out:
# ...
#
# ...

# %%
print(pd.Series)
print(pd.DataFrame)
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
import pandas as pd

data = {
    "Name": {
        'first_name': ["Braund, Mr. Owen Harris", "Allen, Mr. William Henry", "Bonnell, Miss. Elizabeth"],
        'last_name': ["Braund, Mr. Owen Harris", "Allen, Mr. William Henry", "Bonnell, Miss. Elizabeth"]
    },
    "Python": [22, 35, 58],
    "Machine Learning": [60, 70, 84]
}

# Create a MultiIndex from the 'Name' dictionary
arrays = [data["Name"]['first_name'], data["Name"]['last_name']]
multi_index = pd.MultiIndex.from_arrays( arrays, names = ['first_name', 'last_name'])

# Create the DataFrame with the MultiIndex
df = pd.DataFrame(data={"Python": data["Python"], "Machine Learning": data["Machine Learning"]}, index=multi_index)

print(df)
# Out:
#                                                    Python  Machine Learning
# first_name               last_name
# Braund, Mr. Owen Harris  Braund, Mr. Owen Harris       22                60
# Allen, Mr. William Henry Allen, Mr. William Henry      35                70
# Bonnell, Miss. Elizabeth Bonnell, Miss. Elizabeth      58                84

# %%
import pandas as pd
df = pd.DataFrame({"Name": {'first_name':["Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",],'last_name':["Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",]    
},"Python" : [22, 35, 58],"Machine Learning" : [60,70,84]
})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 import pandas as pd
# ----> 2 df = pd.DataFrame({"Name": {'first_name':["Braund, Mr. Owen Harris",
#       3             "Allen, Mr. William Henry",
#       4             "Bonnell, Miss. Elizabeth",],'last_name':["Braund, Mr. Owen Harris",
#       5             "Allen, Mr. William Henry",
#       6             "Bonnell, Miss. Elizabeth",]
#       7 },"Python" : [22, 35, 58],"Machine Learning" : [60,70,84]
#       8 })
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:767, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     761     mgr = self._init_mgr(
#     762         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     763     )
#     765 elif isinstance(data, dict):
# ...

# %%
df = {"Name": ["Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",    
        ],"Python" : [22, 35, 58],"Machine Learning" : [60,70,84]
}

# %%
print(df)
# Out:
# {'Name': ['Braund, Mr. Owen Harris', 'Allen, Mr. William Henry', 'Bonnell, Miss. Elizabeth'], 'Python': [22, 35, 58], 'Machine Learning': [60, 70, 84]}

# %%
data =[
    ["Pratik", 89, 90],
    ["Purvesh", 78, 59],
    ["Jay", 75, 89],
    ["Sandesh", 89, 78],
    ["Raj", 89, 76]
]

colname = ["Name", "Python", "Machine Learning"]

df2 = pd.DataFrame(data, columns=colname)

# %%
df
# Out:
#                        Name  Python  Machine Learning
# 0   Braund, Mr. Owen Harris      22                60
# 1  Allen, Mr. William Henry      35                70
# 2  Bonnell, Miss. Elizabeth      58                84

# %%
df['Name']
# Out:
# 0     Braund, Mr. Owen Harris
# 1    Allen, Mr. William Henry
# 2    Bonnell, Miss. Elizabeth
# Name: Name, dtype: object

# %%
names = ["Jay", "Kumar", "Suraj", "Divya", "Raj"]
s1 = pd.Series(data=names,index=['a','b','c','d','e'])

# %%
d = {
    "a":"Jay",
    "b": "Kumar",
    "c": "Suraj",
    "d": "Divya",
    "e": "Raj"
}

s2 = pd.Series(d,name="names")

# %%
df3 = pd.DataFrame(s2)
df3
# Out:
#    names
# a    Jay
# b  Kumar
# c  Suraj
# d  Divya
# e    Raj

# %%
df3.names == 'Raj' # Searching Raj inside DataFrame It gives the Bool Series
# Out:
# a    False
# b    False
# c    False
# d    False
# e     True
# Name: names, dtype: bool

# %%
df3[df3.names=="Raj"] # To get the Data
# Out:
#   names
# e   Raj

# %%
data = {
    "Name":["Pratik", "Purvesh", "Jay", "Sandesh", "Raj"],
    "Python": [89, 78, 75, 89, 89],
    "Machine Learning": [90, 59, 89, 78, 76]
}

df= pd.DataFrame(data, index=["rank1", "rank2", "rank3", "rank4", "rank5"])

# %%
df
# Out:
#           Name  Python  Machine Learning
# rank1   Pratik      89                90
# rank2  Purvesh      78                59
# rank3      Jay      75                89
# rank4  Sandesh      89                78
# rank5      Raj      89                76

# %%
import numpy as np # Generating Data with the help of numpy 
data=np.random.randn(10, 4) #random value between 0 and 1 and shape of 10 row and 4 col
data
# Out:
# array([[-0.24727185, -0.38315918,  0.23029262, -1.73836488],
#        [ 0.01419774, -0.84823089,  0.86452841, -0.40077789],
#        [-0.98308985,  0.35158297,  0.28535121,  0.45561591],
#        [ 0.31459918, -1.25011983, -0.73690433,  1.32431929],
#        [ 0.00964587,  0.0740468 , -1.58236154,  1.11769718],
#        [-0.09464346, -0.73845018, -0.3634173 ,  0.31732341],
#        [ 0.12942693,  1.10479104, -0.39186369, -0.52808057],
#        [-0.43082486,  1.50791878,  1.27797409, -0.94218773],
#        [-0.72728967,  1.15814636, -2.0077282 , -1.83531798],
#        [-0.05861493, -0.70186135, -0.37330243,  0.94032665]])

# %%
print(df[['Name',"Python"]])# to access multiple series
# Out:
#           Name  Python
# rank1   Pratik      89
# rank2  Purvesh      78
# rank3      Jay      75
# rank4  Sandesh      89
# rank5      Raj      89

# %% [markdown]
# # Load Data From CSV

# %% [markdown]
# pandas provides the read_csv() function to read data stored as a csv file into a pandas DataFrame. pandas supports many different file formats or data sources out of the box (csv, excel, sql, json, parquet, …), each of them with the prefix read_*.

# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.1-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.1-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install kagglehub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("khushikyad001/screen-time-and-app-usage-dataset-iosandroid")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 153k/153k [00:00<00:00, 257kB/s]
# Extracting files...
# Path to dataset files: C:\Users\admin\.cache\kagglehub\datasets\khushikyad001\screen-time-and-app-usage-dataset-iosandroid\versions\1

# %%
import pandas as pd
# df = pd.read_csv("customer and payments.csv")
# df = pd.read_csv(r"C:\Users\admin\Project\Jupyter Projects\customer and payments.csv")
df = pd.read_csv(r"screen_time_app_usage_dataset.csv")

# %% [markdown]
# Getting data in to pandas from many different file formats or data sources is supported by read_* functions.
#
# Exporting data out of pandas is provided by different to_*methods.
#
# The head/tail/info methods and the dtypes attribute are convenient for a first check.

# %% [markdown]
# ### Know your DataFrame

# %%
df.dtypes
# Out:
# user_id               int64
# date                 object
# app_name             object
# category             object
# screen_time_min     float64
# launches              int64
# interactions          int64
# is_productive          bool
# youtube_views       float64
# youtube_likes       float64
# youtube_comments    float64
# extra_col_11        float64
# extra_col_12        float64
# extra_col_13        float64
# extra_col_14        float64
# extra_col_15        float64
# extra_col_16        float64
# extra_col_17        float64
# extra_col_18        float64
# extra_col_19        float64
# extra_col_20        float64
# extra_col_21        float64
# extra_col_22        float64
# extra_col_23        float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     32 non-null     int64
#  1   first_name      32 non-null     object
#  2   last_name       32 non-null     object
#  3   email           32 non-null     object
#  4   phone           32 non-null     object
#  5   address         32 non-null     object
#  6   payment_id      30 non-null     float64
#  7   payment_date    30 non-null     object
#  8   amount          30 non-null     float64
#  9   payment_method  30 non-null     object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 2.6+ KB

# %%
df.columns
# Out:
# Index(['user_id', 'date', 'app_name', 'category', 'screen_time_min',
#        'launches', 'interactions', 'is_productive', 'youtube_views',
#        'youtube_likes', 'youtube_comments', 'extra_col_11', 'extra_col_12',
#        'extra_col_13', 'extra_col_14', 'extra_col_15', 'extra_col_16',
#        'extra_col_17', 'extra_col_18', 'extra_col_19', 'extra_col_20',
#        'extra_col_21', 'extra_col_22', 'extra_col_23'],
#       dtype='object')

# %%
df.rename(columns={'date':"date_time"},inplace=True)

# %%
df
# Out:
#       user_id                      date_time         app_name       category  \
# 0        1051  2024-01-01 00:00:00.000000000           Camera      Utilities
# 1        1088  2024-01-01 00:43:41.673891297           Chrome      Utilities
# 2        1052  2024-01-01 01:27:23.347782594          Spotify  Entertainment
# 3        1028  2024-01-01 02:11:05.021673891      Google Maps      Utilities
# 4        1034  2024-01-01 02:54:46.695565188        Instagram         Social
# ...       ...                            ...              ...            ...
# 2995     1086  2024-03-31 21:05:13.304434812           Camera      Utilities
# 2996     1068  2024-03-31 21:48:54.978326109          Netflix  Entertainment
# 2997     1081  2024-03-31 22:32:36.652217406  Microsoft Teams   Productivity
# 2998     1038  2024-03-31 23:16:18.326108703         WhatsApp         Social
# 2999     1089  2024-04-01 00:00:00.000000000            Gmail      Utilities
#
# ...

# %% [markdown]
# DataFrame.shape is an attribute ,do not use parentheses for attributes of a pandas Series and DataFrame containing the number of rows and columns: (nrows, ncolumns). A pandas Series is 1-dimensional and only the number of rows is returned.

# %%
print("Total Dimention",df.ndim)
print("Shape",df.shape)
print("Total number of element",df.size)
# Out:
# Total Dimention 2
# Shape (3000, 24)
# Total number of element 72000

# %%
df.head() #head() shows the top 5 rows the number of record can be specified 
df.head(3)
# df["youtube_comments"]
# Out:
#    user_id                      date_time app_name       category  \
# 0     1051  2024-01-01 00:00:00.000000000   Camera      Utilities
# 1     1088  2024-01-01 00:43:41.673891297   Chrome      Utilities
# 2     1052  2024-01-01 01:27:23.347782594  Spotify  Entertainment
#
#    screen_time_min  launches  interactions  is_productive  youtube_views  \
# 0            24.53         2             7          False            NaN
# 1            19.78         3             2          False            NaN
# 2            32.03         1             6          False            NaN
#
#    youtube_likes  ...  extra_col_14  extra_col_15  extra_col_16  extra_col_17  \
# 0            NaN  ...         33.43         49.03         64.74         49.49
# 1            NaN  ...         44.06         49.40         66.63         62.10
# 2            NaN  ...         55.18         41.87         54.84         65.59
#
#    extra_col_18  extra_col_19  extra_col_20  extra_col_21  extra_col_22  \
# ...

# %% [markdown]
# Indexing and Slicing

# %%
df.tail() #tail() same as head difference is that it fetch from last
df.tail(3)
# Out:
#     customer_id  first_name last_name                  email           phone  \
# 29           20         Ira    Pillai   ira.pillai@email.com  91-09876-54321
# 30           21      Ranjan    Tiwari      tiwari@google.com  +91 9359208460
# 31           22  Rameshwari    Saluke  SalukeRamesh@mail.com  +91 2349282912
#
#                       address  payment_id payment_date  amount payment_method
# 29  808 Tagore Lane, Ludhiana        40.0   2024-03-10    45.0           Cash
# 30          Mumbai Maharastra         NaN          NaN     NaN            NaN
# 31            Pune Maharastra         NaN          NaN     NaN            NaN

# %% [markdown]
# ### Access Values

# %%
print(df["app_name"][1])
print(df.iloc[2,1]) #accessing row it uses number for idntifying position value
# Out:
# Chrome
# 2024-01-01 01:27:23.347782594

# %% [markdown]
# The inner square brackets define a Python list with column names, whereas the outer brackets are used to select the data from a pandas DataFrame as seen in the previous example.

# %%
print(df.loc[:3,["app_name",'category']]) #accesing with slicing and specific columns
print('\n\n\n This is using query() \n')
print((df.query('app_name=="Spotify"')[['date_time','app_name']])) #To select multiple columns, use a list of column names within the selection brackets []
# Out:
#       app_name       category
# 0       Camera      Utilities
# 1       Chrome      Utilities
# 2      Spotify  Entertainment
# 3  Google Maps      Utilities
#
#
#
#  This is using query()
#
#                           date_time app_name
# 2     2024-01-01 01:27:23.347782594  Spotify
# 33    2024-01-02 00:01:55.238412804  Spotify
# 42    2024-01-02 06:35:10.303434478  Spotify
# 84    2024-01-03 13:10:20.606868956  Spotify
# 125   2024-01-04 19:01:49.236412137  Spotify
# ...                             ...      ...
# 2906  2024-03-29 04:16:24.328109370  Spotify
# 2927  2024-03-29 19:33:59.479826609  Spotify
# 2940  2024-03-30 05:02:01.240413471  Spotify
# 2984  2024-03-31 13:04:34.891630544  Spotify
# 2992  2024-03-31 18:54:08.282760921  Spotify
#
# [159 rows x 2 columns]

# %% [markdown]
# ### Apply Condition

# %%
name='Rajput'
df.query("last_name == @name ")
# Out:
#     customer_id first_name last_name                   email           phone  \
# 14            8      Sanya    Rajput  sanya.rajput@email.com  91-21098-76543
# 15            8      Sanya    Rajput  sanya.rajput@email.com  91-21098-76543
#
#                         address  payment_id payment_date  amount  \
# 14  505 Patel Street, Ahmedabad        28.0   2024-02-15   110.0
# 15  505 Patel Street, Ahmedabad        48.0   2024-03-26   120.0
#
#    payment_method
# 14           Cash
# 15           Cash

# %%
in_list_of_value = df[df["first_name"].isin(['Shaan','Arjun'])]
in_list_of_value
# Out:
#     customer_id first_name last_name                   email           phone  \
# 4             3      Arjun    Sharma  arjun.sharma@email.com  91-76543-21098
# 5             3      Arjun    Sharma  arjun.sharma@email.com  91-76543-21098
# 26           17      Shaan      Nair    shaan.nair@email.com  91-32109-87654
#
#                          address  payment_id payment_date  amount  \
# 4   789 Gandhi Avenue, Bangalore        23.0   2024-02-05   120.0
# 5   789 Gandhi Avenue, Bangalore        43.0   2024-03-16    95.0
# 26       505 Patel Street, Surat        37.0   2024-03-04    85.5
#
#    payment_method
# 4     Credit Card
# 5     Credit Card
# 26    Credit Card

# %%
df[(df['first_name']=="Aisha") & (df["amount"]>50)] #logical operator and(&) and or(|)
# Out:
#    customer_id first_name last_name                  email           phone  \
# 2            2      Aisha     Kumar  aisha.kumar@email.com  91-87654-32109
#
#                    address  payment_id payment_date  amount payment_method
# 2  456 Nehru Street, Delhi        22.0   2024-02-03    75.5         PayPal

# %%
df.query("`first_name`=='Aisha' and `amount`==75.5")#logical operator and , or with query also make use of backtik `` for column name if there is space or other python keyword
# Out:
#    customer_id first_name last_name                  email           phone  \
# 2            2      Aisha     Kumar  aisha.kumar@email.com  91-87654-32109
#
#                    address  payment_id payment_date  amount payment_method
# 2  456 Nehru Street, Delhi        22.0   2024-02-03    75.5         PayPal

# %% [markdown]
# #### set inplace = True

# %%
df_copy = df.copy()
df_copy.query("amount>100",inplace=True)
df_copy
# Out:
#     customer_id first_name last_name                     email  \
# 4             3      Arjun    Sharma    arjun.sharma@email.com
# 14            8      Sanya    Rajput    sanya.rajput@email.com
# 15            8      Sanya    Rajput    sanya.rajput@email.com
# 24           15    Reyansh    Thakur  reyansh.thakur@email.com
# 28           19      Arnav     Menon     arnav.menon@email.com
#
#              phone                            address  payment_id  \
# 4   91-76543-21098       789 Gandhi Avenue, Bangalore        23.0
# 14  91-21098-76543        505 Patel Street, Ahmedabad        28.0
# 15  91-21098-76543        505 Patel Street, Ahmedabad        48.0
# 24  91-54321-09876            303 Jinnah Road, Nagpur        35.0
# 28  91-10987-65432  707 Azad Road, Thiruvananthapuram        39.0
#
#    payment_date  amount payment_method
# 4    2024-02-05   120.0    Credit Card
# 14   2024-02-15   110.0           Cash
# 15   2024-03-26   120.0           Cash
# ...

# %%
df_copy.reset_index(drop=True)  #to reset index
# Out:
#    customer_id first_name last_name                     email           phone  \
# 0            3      Arjun    Sharma    arjun.sharma@email.com  91-76543-21098
# 1            8      Sanya    Rajput    sanya.rajput@email.com  91-21098-76543
# 2            8      Sanya    Rajput    sanya.rajput@email.com  91-21098-76543
# 3           15    Reyansh    Thakur  reyansh.thakur@email.com  91-54321-09876
# 4           19      Arnav     Menon     arnav.menon@email.com  91-10987-65432
#
#                              address  payment_id payment_date  amount  \
# 0       789 Gandhi Avenue, Bangalore        23.0   2024-02-05   120.0
# 1        505 Patel Street, Ahmedabad        28.0   2024-02-15   110.0
# 2        505 Patel Street, Ahmedabad        48.0   2024-03-26   120.0
# 3            303 Jinnah Road, Nagpur        35.0   2024-02-29   120.0
# 4  707 Azad Road, Thiruvananthapuram        39.0   2024-03-08   110.0
#
#   payment_method
# 0    Credit Card
# 1           Cash
# 2           Cash
# ...

# %% [markdown]
# ### drop Column

# %%
df_copy.drop("payment_id",axis=1,inplace=True)

# %%
df_copy.drop(columns=["customer_id","last_name"],inplace=True)
#changes are never made inside DataFrame unless there is inplace is set to True

# %%
df_copy.reset_index(drop=True,inplace=True)

# %%
df_copy.drop(labels='address',axis=1,inplace=True)

# %%
df_copy
# Out:
#   first_name                     email           phone payment_date  amount  \
# 0      Arjun    arjun.sharma@email.com  91-76543-21098   2024-02-05   120.0
# 1      Sanya    sanya.rajput@email.com  91-21098-76543   2024-02-15   110.0
# 2      Sanya    sanya.rajput@email.com  91-21098-76543   2024-03-26   120.0
# 3    Reyansh  reyansh.thakur@email.com  91-54321-09876   2024-02-29   120.0
# 4      Arnav     arnav.menon@email.com  91-10987-65432   2024-03-08   110.0
#
#   payment_method
# 0    Credit Card
# 1           Cash
# 2           Cash
# 3    Credit Card
# 4    Credit Card

# %% [markdown]
# ### Add Column

# %%
month = ['fab','fab','fab','mar','mar']
df_copy=df_copy.assign(Payment_month=month) #adding column with assign method # multiple columns can be added to the DataFrame by using " , "

# %%
df_copy['average_amount']=0  #adding static Value

# %%
df_copy
# Out:
#   first_name                     email           phone payment_date  amount  \
# 0      Arjun    arjun.sharma@email.com  91-76543-21098   2024-02-05   120.0
# 1      Sanya    sanya.rajput@email.com  91-21098-76543   2024-02-15   110.0
# 2      Sanya    sanya.rajput@email.com  91-21098-76543   2024-03-26   120.0
# 3    Reyansh  reyansh.thakur@email.com  91-54321-09876   2024-02-29   120.0
# 4      Arnav     arnav.menon@email.com  91-10987-65432   2024-03-08   110.0
#
#   payment_method Payment_month  average_amount
# 0    Credit Card           fab               0
# 1           Cash           fab               0
# 2           Cash           fab               0
# 3    Credit Card           mar               0
# 4    Credit Card           mar               0

# %%
df_copy.insert(1,'last_name',['yadav','khan','choube','thakur','mirza']) #inserting column to specific Index
df_copy
# Out:
#   first_name last_name                     email           phone payment_date  \
# 0      Arjun     yadav    arjun.sharma@email.com  91-76543-21098   2024-02-05
# 1      Sanya      khan    sanya.rajput@email.com  91-21098-76543   2024-02-15
# 2      Sanya    choube    sanya.rajput@email.com  91-21098-76543   2024-03-26
# 3    Reyansh    thakur  reyansh.thakur@email.com  91-54321-09876   2024-02-29
# 4      Arnav     mirza     arnav.menon@email.com  91-10987-65432   2024-03-08
#
#    amount payment_method Payment_month  average_amount
# 0   120.0    Credit Card           fab               0
# 1   110.0           Cash           fab               0
# 2   120.0           Cash           fab               0
# 3   120.0    Credit Card           mar               0
# 4   110.0    Credit Card           mar               0

# %% [markdown]
# ### Rename Column

# %%
df_copy.columns.values[-1]="Days_since_last_visit"

# %%
df_copy
# Out:
#   first_name last_name                     email           phone payment_date  \
# 0      Arjun     yadav    arjun.sharma@email.com  91-76543-21098   2024-02-05
# 1      Sanya      khan    sanya.rajput@email.com  91-21098-76543   2024-02-15
# 2    Reyansh    choube  reyansh.thakur@email.com  91-54321-09876   2024-02-29
# 3      Arnav    thakur     arnav.menon@email.com  91-10987-65432   2024-03-08
# 4      Sanya     mirza    sanya.rajput@email.com  91-21098-76543   2024-03-26
#
#    amount payment_method Payment_month  Days_since_last_visit
# 0   120.0    Credit Card           fab                      0
# 1   110.0           Cash           fab                      0
# 2   120.0    Credit Card           fab                      0
# 3   110.0    Credit Card           mar                      0
# 4   120.0           Cash           mar                      0

# %% [markdown]
# ### Data Type Conversion

# %%
df_copy.payment_date=pd.to_datetime(df_copy.payment_date).dt # df['payment_date'] = df['payment_date'].apply(pd.to_datetime)
df_copy.amount = df_copy.amount.astype('int')

# %%
df_copy.dtypes
# Out:
# first_name                       object
# last_name                        object
# email                            object
# phone                            object
# payment_date             datetime64[ns]
# amount                            int32
# payment_method                   object
# Payment_month                    object
# Days_since_last_visit           float64
# Days_since_last_visit           float64
# dtype: object

# %%
df_copy
# Out:
#   first_name last_name                     email           phone payment_date  \
# 0      Arjun     yadav    arjun.sharma@email.com  91-76543-21098   2024-02-05
# 1      Sanya      khan    sanya.rajput@email.com  91-21098-76543   2024-02-15
# 2    Reyansh    choube  reyansh.thakur@email.com  91-54321-09876   2024-02-29
# 3      Arnav    thakur     arnav.menon@email.com  91-10987-65432   2024-03-08
# 4      Sanya     mirza    sanya.rajput@email.com  91-21098-76543   2024-03-26
#
#    amount payment_method Payment_month  Days_since_last_visit
# 0     120    Credit Card           fab                      0
# 1     110           Cash           fab                      0
# 2     120    Credit Card           fab                      0
# 3     110    Credit Card           mar                      0
# 4     120           Cash           mar                      0

# %% [markdown]
# ### Assign value to series

# %%
import numpy as np
df_copy = df_copy.assign(Days_since_last_visit=lambda df:(pd.to_datetime('2024-04-01') - df['payment_date'])/np.timedelta64(1,'D'))
df_copy
# Out:
#   first_name last_name                     email           phone payment_date  \
# 0      Arjun     yadav    arjun.sharma@email.com  91-76543-21098   2024-02-05
# 1      Sanya      khan    sanya.rajput@email.com  91-21098-76543   2024-02-15
# 2    Reyansh    choube  reyansh.thakur@email.com  91-54321-09876   2024-02-29
# 3      Arnav    thakur     arnav.menon@email.com  91-10987-65432   2024-03-08
# 4      Sanya     mirza    sanya.rajput@email.com  91-21098-76543   2024-03-26
#
#    amount payment_method Payment_month  Days_since_last_visit
# 0     120    Credit Card           fab                   56.0
# 1     110           Cash           fab                   46.0
# 2     120    Credit Card           fab                   32.0
# 3     110    Credit Card           mar                   24.0
# 4     120           Cash           mar                    6.0

# %%
df_copy['Months_since_last_visit']=(np.round(df_copy.Days_since_last_visit /31))
df_copy
# Out:
#   first_name last_name                     email           phone payment_date  \
# 0      Arjun     yadav    arjun.sharma@email.com  91-76543-21098   2024-02-05
# 1      Sanya      khan    sanya.rajput@email.com  91-21098-76543   2024-02-15
# 2    Reyansh    choube  reyansh.thakur@email.com  91-54321-09876   2024-02-29
# 3      Arnav    thakur     arnav.menon@email.com  91-10987-65432   2024-03-08
# 4      Sanya     mirza    sanya.rajput@email.com  91-21098-76543   2024-03-26
#
#    amount payment_method Payment_month  Days_since_last_visit  \
# 0     120    Credit Card           fab                   56.0
# 1     110           Cash           fab                   46.0
# 2     120    Credit Card           fab                   32.0
# 3     110    Credit Card           mar                   24.0
# 4     120           Cash           mar                    6.0
#
#    Months_since_last_visit
# 0                      2.0
# 1                      1.0
# 2                      1.0
# ...

# %%
df_copy.describe()#The describe() method provides a quick overview of the numerical data in a DataFrame. As the Name and Sex columns are textual data, these are by default not taken into account by the describe() method.
# Out:
#               payment_date      amount  Days_since_last_visit  \
# count                    5    5.000000               5.000000
# mean   2024-02-28 04:48:00  116.000000              32.800000
# min    2024-02-05 00:00:00  110.000000               6.000000
# 25%    2024-02-15 00:00:00  110.000000              24.000000
# 50%    2024-02-29 00:00:00  120.000000              32.000000
# 75%    2024-03-08 00:00:00  120.000000              46.000000
# max    2024-03-26 00:00:00  120.000000              56.000000
# std                    NaN    5.477226              19.421637
#
#        Months_since_last_visit
# count                 5.000000
# mean                  1.000000
# min                   0.000000
# 25%                   1.000000
# 50%                   1.000000
# 75%                   1.000000
# max                   2.000000
# std                   0.707107

# %% [markdown]
# ## Drop Rows From DataFrame
#
# By using pandas.DataFrame.drop() method you can drop/remove/delete rows from DataFrame. axis param is used to specify what axis you would like to remove. By default axis = 0 meaning to remove rows. Use axis=1 or columns param to remove columns. By default, Pandas return a copy DataFrame after deleting rows, used inpalce=True to remove from existing referring DataFrame.
# DataFrame.drop(labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors='raise')

# %%
df_copy.drop(index=[1,2]) #inplace is False so this command won't afffect the actual DataFrame instead it returns the filtered output
# Out:
#   first_name last_name                   email           phone payment_date  \
# 0      Arjun     yadav  arjun.sharma@email.com  91-76543-21098   2024-02-05
# 3      Arnav    thakur   arnav.menon@email.com  91-10987-65432   2024-03-08
# 4      Sanya     mirza  sanya.rajput@email.com  91-21098-76543   2024-03-26
#
#    amount payment_method Payment_month  Days_since_last_visit  \
# 0     120    Credit Card           fab                   56.0
# 3     110    Credit Card           mar                   24.0
# 4     120           Cash           mar                    6.0
#
#    Months_since_last_visit
# 0                      2.0
# 3                      1.0
# 4                      0.0

# %%
df_copy.drop(index=[0,1],axis=0)   #Delete row by index
# Out:
#   first_name last_name                     email           phone payment_date  \
# 2    Reyansh    choube  reyansh.thakur@email.com  91-54321-09876   2024-02-29
# 3      Arnav    thakur     arnav.menon@email.com  91-10987-65432   2024-03-08
# 4      Sanya     mirza    sanya.rajput@email.com  91-21098-76543   2024-03-26
#
#    amount payment_method Payment_month  Days_since_last_visit  \
# 2     120    Credit Card           fab                   32.0
# 3     110    Credit Card           mar                   24.0
# 4     120           Cash           mar                    6.0
#
#    Months_since_last_visit
# 2                      1.0
# 3                      1.0
# 4                      0.0

# %%
df_copy.drop(df_copy.index[0:3])   ## Delete Rows by Index Range
df_copy.drop(range(0,3))            # Delete row using range function
# Out:
#   first_name last_name                   email           phone payment_date  \
# 3      Arnav    thakur   arnav.menon@email.com  91-10987-65432   2024-03-08
# 4      Sanya     mirza  sanya.rajput@email.com  91-21098-76543   2024-03-26
#
#    amount payment_method Payment_month  Days_since_last_visit  \
# 3     110    Credit Card           mar                   24.0
# 4     120           Cash           mar                    6.0
#
#    Months_since_last_visit
# 3                      1.0
# 4                      0.0

# %%
# Iterate all rows using DataFrame.iterrows()
print("After iterating all rows:\n")

for index, row in df_copy.iterrows():
    print (f"{index} {(row["first_name"]).ljust(15," ")} paid {row["amount"]} on {row["payment_date"]}") #The ljust method means "left-justify"; this makes sense because your string will be to the left after adjustment up to the specified length.
# Out:
# After iterating all rows:
#
# 0 Arjun           paid 120.0 on 2024-02-05
# 1 Sanya           paid 110.0 on 2024-02-15
# 2 Sanya           paid 120.0 on 2024-03-26
# 3 Reyansh         paid 120.0 on 2024-02-29
# 4 Arnav           paid 110.0 on 2024-03-08

# %% [markdown]
# ### Append DataFrame

# %%
df1 = pd.read_csv(r"C:\Users\admin\Project\Jupyter Projects\customer and payments.csv")
df2 = pd.read_csv(r"C:\Users\admin\Project\Jupyter Projects\customer and payments.csv")
df3 = pd.concat([df1,df2])

# %%
df3.shape
# Out:
# (64, 10)

# %% [markdown]
# ## Drop Duplicates
# Pandas DataFrame.drop_duplicates() function is used to remove duplicates from the DataFrame rows and columns. When data preprocessing and analysis step, data scientists need to check for any duplicate data is present, if so need to figure out a way to remove the duplicates.

# %%
df3.drop_duplicates().shape
# Out:
# (32, 10)

# %% [markdown]
# ### Groupby

# %%
result = df.groupby(by="first_name",sort=False).count()
result.customer_id
# Out:
# first_name
# Aarav         2
# Aisha         2
# Arjun         2
# Ishika        2
# Rohan         2
# Ananya        2
# Aryan         2
# Sanya         2
# Vivaan        2
# Zara          2
# Aaradhya      1
# Vihaan        1
# Advait        1
# Myra          1
# Reyansh       1
# Ishani        1
# Shaan         1
# Zoya          1
# Arnav         1
# Ira           1
# Ranjan        1
# Rameshwari    1
# Name: customer_id, dtype: int64

# %%
print(df.groupby(by=["payment_method",'first_name'])['amount'].aggregate(['min','max','sum','count']))
print(result.dtypes)
print(df.groupby('payment_method')['amount'].mean())
# Out:
#                               min     max     sum  count
# payment_method first_name
# Cash           Ira          45.00   45.00   45.00      1
#                Ishani       50.00   50.00   50.00      1
#                Ishika       32.50   45.00   77.50      2
#                Sanya       110.00  120.00  230.00      2
#                Vihaan       40.50   40.50   40.50      1
# Credit Card    Aaradhya     80.00   80.00   80.00      1
#                Aarav        60.00  100.00  160.00      2
#                Advait       65.00   65.00   65.00      1
#                Arjun        95.00  120.00  215.00      2
#                Arnav       110.00  110.00  110.00      1
#                Aryan        28.00   30.50   58.50      2
#                Reyansh     120.00  120.00  120.00      1
#                Rohan        78.25   90.25  168.50      2
#                Shaan        85.50   85.50   85.50      1
#                Vivaan       75.75   90.75  166.50      2
# ...

# %% [markdown]
# <img src="https://pandas.pydata.org/docs/_images/02_io_readwrite.svg" style="background-color : white">

# %%
df.to_csv("result.csv", index=False)

# %%
df1 = pd.DataFrame(
    {
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    },
    index=[0, 1, 2, 3],
)
df4 = pd.DataFrame(
    {
        "B": ["B2", "B3", "B6", "B7"],
        "D": ["D2", "D3", "D6", "D7"],
        "F": ["F2", "F3", "F6", "F7"],
    },
    index=[2, 3, 6, 7],
)
pd.concat([df1,df4],axis=1,join="outer")
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7
